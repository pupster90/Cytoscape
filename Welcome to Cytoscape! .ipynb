# %%
# %run embed.ipynb  #<-- Loads Cytoscape
# Out:
# <script>var py = Jupyter.notebook.kernel</script>
# <style>
# #node_table_body tr td, #edge_table_body tr td {
#     padding: 2px;
# }
# #node_table_body tr td input, #edge_table_body tr td input {
#     height: 100%;
#     width: 100%;
#     border: 0px;
#     text-align: center;
# }
# </style>
# <script>
# cy.io.saveNdex = Jupyter.notebook.kernel.comm_manager.new_comm( 'saveNdexComm' );
# </script>

# %%
HTML("""
<div class="row"><div class="col-xs-12 col-md-offset-3 col-md-6">
<div class="embed-responsive embed-responsive-16by9">
  <iframe class="embed-responsive-item" 
  src='https://www.youtube.com/embed/SrREjZSPqBI'></iframe></div>
</div></div>
""")
# Out:
# <div class="row"><div class="col-xs-12 col-md-offset-3 col-md-6">
# <div class="embed-responsive embed-responsive-16by9">
#   <iframe class="embed-responsive-item"
#   src='https://www.youtube.com/embed/SrREjZSPqBI'></iframe></div>
# </div></div>

# %% [markdown]
# <img class="img-responsive" width="30%" src="http://www.cytoscape.org/images/cytoscape3_logo.png" alt="logo">

# %%
#cyto_btn = Button(description='Start Cytoscape!',button_style='warning')
#def cyto_btn_click(b):
#    Graph.js.load()
#    cyto_btn.disabled = True
#cyto_btn.on_click( cyto_btn_click )

#HBox( [cyto_btn],  layout= ipw.Layout(justify_content='center') )

# %%
display( Graph.html.cy )
# Out:
# <style>.cy{
#     width: 100%;
#     height: 50vw;
#     border-style: solid;
#     border-width: 1px;
# }</style>
# <div id='cy' class='cy'></div>

# %%
display( Graph.box.editor )

# %%
display( Graph.html.table )
# Out:
# <h2 style='color: DarkKhaki'>Nodes</h2>
# <table id="node_table" class="table table-striped table-bordered">
#     <thead><tr id="node_table_head"></tr></thead>
#     <tbody id="node_table_body"></tbody>
# </table>
#
# <h2 style='color: purple'>Edges</h2>
# <table id="edge_table" class="table table-striped table-bordered">
#     <thead><tr id="edge_table_head"></tr></thead>
#     <tbody id="edge_table_body"></tbody>
# </table>

# %%
display( Graph.box.loadSave )
# Out:
# Accordion(children=(VBox(children=(ToggleButtons(button_style='success', layout=Layout(justify_content='center…

# %%
Graph.js.load()
# Out:
# <script>
# var cy;
# require(['cytoscape'], function(cytoscape){
#     cy = cytoscape({ container: document.getElementById('cy') });
#
# cy.io = {}       // <-- where we store all the parameters/variables we create
# cy.maxZoom(14)   // <-- Determine how much window zooms in and out
# cy.minZoom(.4)
#
# // Create default style for nodes and edges
# cy.io.style = {}
#
# cy.io.style.node = { 'overlay-color': 'gray', 'overlay-padding': '2px', 'background-color': 'gray', 'text-background-color':'white',
#                         'text-border-width':'2px', 'text-background-padding':'4px', 'z-index-compare':'manual', 'z-index':'1',
#                         'border-color': 'gray'}   //cant get this to work: 'backgroundFit':'cover' , 'background-fit':'cover'
#
# cy.io.style.edge = { 'overlay-color': 'gray', 'overlay-padding': '8px', 'line-color': 'gray', 'curve-style': 'bezier', 'text-background-color':'white',
# ...

# %% [markdown]
# # <font color="orange">old: </font> Isolate nodes and edges

# %%
df_data = Graph.data

# %% [markdown]
# Split Nodes and Edges

# %%
df_nodes = df_data[ df_data.type == "node"].drop(["type"], axis=1)
df_edges = df_data[ df_data.type == "edge"].drop(["type"], axis=1)

# %%
df_nodes

# %%
df_edges = df_data[ df_data.type == "edge"].drop(["type"], axis=1)

# %%
df_edges

# %% [markdown]
# # Add Data Objects

# %% [markdown]
# Varialbe shoudl be set to either 'Node' or 'Edge'
# ``` python
# Graph.w.var_create_select
# ```
# Variable should be set to 'Number', 'Text'
# ``` python
# Graph.w.var_create_type
# ```
# Then "click" this
# ``` python
# Graph.w.var_create_btn
# ```

# %%
df_data_old = df_data

# %%
df_data
# Out:
#                                      id label   num  \
# 0  614bf4a3-c00b-4c9f-ab92-7919b147f3db         NaN
# 1  7ee005db-155f-4f42-be56-0cce453177e1         NaN
# 2  7d906290-57b0-4048-aa43-e57c61106d07         NaN
# 3  bb2707d8-9d17-474d-a8cd-613bb1bb6e97        34.0
#
#                                  source source-shape  \
# 0
# 1
# 2
# 3  7ee005db-155f-4f42-be56-0cce453177e1         none
#
#                                  target target-shape       textit  type
# 0                                                     Howdy dowdy  node
# 1                                                             NaN  node
# 2                                                             NaN  node
# 3  7d906290-57b0-4048-aa43-e57c61106d07         none          NaN  edge

# %% [markdown]
# ## Scratch Paper

# %%
df_nodes = df_data[ df_data.type == "node"].drop(["type", "id", "source","source-shape", "target", "target-shape", "label"], axis=1)

# %%
df_nodes
# Out:
#    num       textit
# 0  NaN  Howdy dowdy
# 1  NaN          NaN
# 2  NaN          NaN

# %%
node_edge
df_smaller = df_nodes = df_data[ df_data.type == "node"].drop(["type", "id", "source","source-shape", "target", "target-shape", "label"], axis=1)
for column in df_nodes :
    if not df_nodes[column].isnull().all(): # If there's data inside column
        df_nodes[ df_nodes["textit"].first_valid_index() ]
# Out:
# textit

# %%
df_nodes["num"].first_valid_index()

# %%
df_nodes["textit"].first_valid_index()
# Out:
# 0

# %%
df_nodes["textit"].first_valid_index()

# %% [markdown]
# ## Add Data Second Try

# %%
for data_type in ["node","edge"]:   #print(" ");print(data_type)
    Graph.w.var_create_select.value = data_type.capitalize() #<-- set "Variables" widget's node/edge datatype
    df_smaller = df_data[ df_data.type == data_type ].drop(["type", "id", "source","source-shape", "target", "target-shape", "label"], axis=1) #display(df_smaller)
    for column in df_smaller : #<-- for each column of data user created  #print(column)
        if not df_smaller[column].isnull().all(): # If there's data inside column
            is_num =  type(df_data[column].values[ df_data[column].first_valid_index() ]) == type(np.float64()) 
            Graph.w.var_create_type.value = "Number" if is_num else "Text"       #<-- set "Variables" widget's num/text datatype
            Graph.w.var_create_text.value = column
            Graph.w.var_create_btn.click()                  #<-- add the datatype to the "Variables" section of the editor box

# %% [markdown]
# ### Other junk

# %%
df_smaller.values[ df_smaller[column].first_valid_index() ]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-ec94f994fa9a> in <module>
# ----> 1 df_smaller.values[ df_smaller[column].first_valid_index() ]
#
# IndexError: index 3 is out of bounds for axis 0 with size 1

# %%
Graph.w.var_create_type.value
# Out:
# 'Text'

# %%
node_data_raw = df_nodes.drop(["id","label","source","target","source-shape","target-shape"], axis=1)

# %%
np.float64()

# %%
data_type.capitalize()
# Out:
# 'Edge'

# %%
Graph.w.var_create_btn.click()
# Out:
# <bound method Button.click of Button(button_style='primary', description='Create', layout=Layout(width='auto'), style=ButtonStyle())>

# %%
df_smaller[column]
# Out:
# 3    34.0
# Name: num, dtype: float64

# %%
df_smaller[column]
# Out:
# 3    34.0
# Name: num, dtype: float64

# %%
df_smaller[column]
# Out:
# 0    Howdy dowdy
# 1            NaN
# 2            NaN
# Name: textit, dtype: object

# %%
column
# Out:
# 'textit'

# %%
df_data.numey

# %%
type( df_data.numey[0] ) == type(np.float64())

# %% [markdown]
# ## Add Edge Data

# %%
edges_data_raw = df_edges.drop(["id","label","source","target","source-shape","target-shape"], axis=1)

# %%
edges_data_raw

# %%
for column in edges_data_raw:
    if not edges_data_raw[column].isnull().all() :   # If there's data inside column
        print(column)

# %% [markdown]
# ### Figure out How get if number or text

# %%
edges_data_raw["num"][ -edges_data_raw["num"].isnull() ].values[0]

# %%
edges_data_raw[column][ -edges_data_raw[column].isnull() ].values

# %% [markdown]
# # Add Nodes and Edges

# %%
df_data
# Out:
#                                      id label   num  \
# 0  614bf4a3-c00b-4c9f-ab92-7919b147f3db         NaN
# 1  7ee005db-155f-4f42-be56-0cce453177e1         NaN
# 2  7d906290-57b0-4048-aa43-e57c61106d07         NaN
# 3  bb2707d8-9d17-474d-a8cd-613bb1bb6e97        34.0
#
#                                  source source-shape  \
# 0
# 1
# 2
# 3  7ee005db-155f-4f42-be56-0cce453177e1         none
#
#                                  target target-shape       textit  type
# 0                                                     Howdy dowdy  node
# 1                                                             NaN  node
# 2                                                             NaN  node
# 3  7d906290-57b0-4048-aa43-e57c61106d07         none          NaN  edge

# %%
for index, row in df_data.iterrows():
    node_edge = "nodes" if row.type == "node" else "edges"
    text = "{group:'"+node_edge+"', data:{ id: '"+row.id+"'" #<-- add node id for row
    # add additional data if there
    for row_id, row_val in row.iteritems():
        if row_id!='id' and row_id!='type' and row_val!='' and row_val==row_val :
            add_var = f"'{row_val}'" if type( row_val ) == type("") else f"{row_val}" #<-- If datatype is number vs string
            text+=f", '{row_id}': {add_var}"
    text+="}  }" #print(text) #print(" ")
    display(Javascript(f"var ele = cy.add({text}); cy.io.style.set( ele )"))

# %% [markdown]
# ## <font color="orange">old: </font>Add Nodes

# %%
for index, row in df_nodes.iterrows():
    text = "{group:'nodes', data:{ id: '"+row.id+"'" #<-- add node id for row
    # add additional data if there
    for row_id, row_val in row.iteritems():
        if row_id!='id' and row_val!='' and row_val==row_val :
            add_var = f"{row_val}" if type( row_val ) == type(np.float64()) else f"'{row_val}'" #<-- If datatype is number vs string
            text+=f", '{row_id}': '{add_var}'"
            
    text+="}  }" #print(text)#print(" ")
    display(Javascript(f"var ele = cy.add({text}); cy.io.style.set( ele )"))

# %%
type(2.0)

# %%
== type(np.float64())

# %% [markdown]
# ## <font color="orange">old: </font> Add Edges

# %%
df_edges

# %%
for index, row in df_edges.iterrows():
    text = "{group:'edges', data:{ id: '"+row.id+"'" #<-- add node id for row
    # add additional data if there
    for row_id, row_val in row.iteritems():
        if row_id!='id' and row_val!='' and row_val==row_val :
            text+=f", '{row_id}': '{row_val}'"
            
    text+="}  }" #print(text)#print(" ")
    display(Javascript(f"var ele = cy.add({text}); cy.io.style.set( ele )"))

# %% [markdown]
# # Add Layout

# %%
display(Javascript("cy.elements().layout({name: 'cose'}).run()"))

# %% [markdown]
# # Check that Data Looks like Original

# %%
Graph.data
